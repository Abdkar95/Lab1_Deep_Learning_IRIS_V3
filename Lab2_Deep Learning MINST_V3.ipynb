# %% [markdown]
# # Deep Learning avec Python (Keras+TF) appliqué aux données Minst

# %% [markdown]
# ##  <font color="orange">installer les packages suivants</font>
# - !pip install pandas
# - !pip install keras
# - !pip install tensorflow
# - !pip install sklearn
# - !pip install matplotlib

# %%
# !python --version

# %%
#pip list

# %% [markdown]
# ##  <font color="orange">1 Chargement des librairies</font>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from tensorflow.keras import Input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Conv2D, MaxPool2D
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.datasets import mnist

# %% [markdown]
# ##  <font color="orange">2 Préparation des données Minst</font>

# %% [markdown]
# ### Charger les données

# %%
from sklearn.model_selection import train_test_split

# récupération des données
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train[0]

# %%
# les données sont transformées pour passer sous un format d’image
# standard avec des valeurs entre 0 et 1
x_train = (x_train/255).reshape(x_train.shape[0], 28, 28,1)
x_test = (x_test/255).reshape(x_test.shape[0], 28, 28,1)

# %% [markdown]
# ### Encoder les données cibles

# %%
pd.DataFrame(y_train).head()

# %%
## encoder les données train et test

# %%
y_train

# %% [markdown]
# ### Visualisation des données

# %%
## Afficher une image avec plt.imshow

# %% [markdown]
# ## <font color="orange">3 Modelisation: Deep learning simple</font>

# %% [markdown]
# #### *Construction du modèle*

# %% [markdown]
# ❓Créer un modèle avec trois couches une couche d'applatissement, une couche cachée de  128 neurones et une couche de sortie adaptée à votre problématique

# %%
# créer le modèle séquentiel

# %% [markdown]
# ❓Combien votre modèle à paramètres ?

# %%
## afficher le résumé du modèle

# %%
# compiler le modèle

# %% [markdown]
# #### *Ajustement du modèle*

# %%
mymodel=

# %% [markdown]
# #### *Prédire les données de test*

# %%
y_test_pred=

# %% [markdown]
# ❓Visualiser les résultats pour l'échantillon 352

# %%
mysample = 352

# %%
# afficher l'image correspondante

# %% [markdown]
# ❓ Transformer les probabilités en modalité la plus vraissemblable

# %%
y_test_class=
y_test_pred_class=

# concatener dans un dataframe
res=pd.concat([pd.DataFrame(y_test_class,columns=['Y']),pd.DataFrame(y_test_pred_class,columns=['Ypred'])], axis=1)
res

# %%
from sklearn.metrics import *

# %% [markdown]
# #### Evaluation à l'aide de la matrice de confusion

# %%
cm =

print(cm)

# %%
plt.plot(mymodel.history['loss'],c='red')
plt.plot(mymodel.history['val_loss'],c='green')

# %% [markdown]
# ❓ visualisé un exemple qui ne fonctionne pas y=9 et ypred=4

# %%
selindex=

# %% [markdown]
# ## <font color="orange">4 Modelisation: Deep learning avec Convolution & Pooling</font>

# %%
# ajouter 32 filtre de convolution 3x3 et ensuite un max pooling 2x2

# %%
# compliler et ajuster
# courbe d'apprentissage
# matrice de confusion
